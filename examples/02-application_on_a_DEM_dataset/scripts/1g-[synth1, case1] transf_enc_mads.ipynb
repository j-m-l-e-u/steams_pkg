# %%
import pandas as pd
import os
import json
import torch
import numpy as np
from torch.utils.data import DataLoader
from steams.data import KVyQVx
from steams.models.transformer import EncoderTransformer2_mads
from steams.trainer import AttentionTrainer,train, evaluation, prediction_prime
from steams.criterion import R2,RMSE,variance
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import geopandas as gpd

# %%
# parent_path = os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), os.pardir))
# parent_dir = os.path.join(parent_path,'results','NWnn3')
# if not os.path.exists(parent_dir):
#     os.makedirs(parent_dir)

parent_dir = os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), os.pardir))

# %%
resdir = os.path.join(parent_dir,'results')
figdir = os.path.join(parent_dir,'fig')
if not os.path.exists(figdir):
    os.makedirs(figdir)
if not os.path.exists(resdir):
    os.makedirs(resdir)

# %%
if torch.cuda.is_available():
    cuda_name = "1"
    num_workers=0
    pin_memory = True
    device = torch.device('cuda'+":"+cuda_name)
    #device = torch.device('cuda')
else:
    num_workers = 4
    pin_memory = False
    device = torch.device('cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## train/valid dataset

# %%
params = {
        "class" : "KVyQVx",
        "Y":{
          "path": "",
          "KEY":["x","y"],
          "VALUE": ["sensor_hq"],
          "nb_location" : 1000,
          "history_length": 0,
          "nb_sampling": 100
        },
        "X":{
          "path": "",
          "QUERY":["x","y"],
          "VALUE": ["sensor_hq"],
          "nb_location" : 1000,
          "gap_length": 0,
          "horizon_length":0,
          "nb_sampling": 100
        }
    }

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_train")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_train")

train_dataset = KVyQVx(params)

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_valid")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_valid")

valid_dataset = KVyQVx(params)

# %%
#train_dataset[0]

# %% [markdown]
# ## model, optimizer, criterion, scheduler

# %%
#model
model = EncoderTransformer2_mads(device,type="krig",kernel="exp", input_k=2,input_q=2, input_v=1, hidden_size=32,dim_feedforward=10,num_blk=2,dropout=0.1)

# %%
# optimzer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) #8e-3
#optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# criterion
criterion = torch.nn.MSELoss()

# AttentionTrainer object
obj = AttentionTrainer(model,device)
obj.init_optimizer(optimizer)
obj.init_criterion(criterion)

# %% [markdown]
# ## Training

# %%
# training
train(obj,train_dataset,valid_dataset,niter=200,n_iter_stop=10,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
#   epoch     train     valid
# 0     0  0.819913  0.705455
#   epoch     train     valid
# 0     1  0.635977  0.526079
#   epoch     train     valid
# 0     2  0.481807  0.395699
#   epoch     train     valid
# 0     3  0.395264  0.341727
#   epoch     train     valid
# 0     4  0.362916  0.321762
#   epoch     train     valid
# 0     5  0.337698  0.290954
#   epoch     train     valid
# 0     6  0.316605  0.277491
#   epoch     train     valid
# 0     7  0.297778  0.255189
#   epoch     train     valid
# 0     8  0.282713  0.239276
#   epoch     train     valid
# 0     9  0.269453  0.223041
#   epoch     train     valid
# 0    10  0.253742  0.203914
#   epoch     train     valid
# 0    11  0.237928  0.187507
#   epoch     train    valid
# 0    12  0.223687  0.17879
#   epoch     train     valid
# 0    13  0.214851  0.174482
#   epoch     train     valid
# 0    14  0.204981  0.165309
#   epoch     train     valid
# 0    15  0.197604  0.155863
#   epoch     train     valid
# 0    16  0.187546  0.145982
#   epoch     train     valid
# 0    17  0.179525  0.141892
#   epoch     train     valid
# 0    18  0.168368  0.136676
#   epoch     train     valid
# 0    19  0.157144  0.125112
#   epoch     train     valid
# 0    20  0.146883  0.121556
#   epoch     train     valid
# 0    21  0.139931  0.116779
#   epoch     train     valid
# 0    22  0.136461  0.113163
#   epoch     train     valid
# 0    23  0.131045  0.110243
#   epoch     train     valid
# 0    24  0.126689  0.105017
#   epoch     train     valid
# 0    25  0.125207  0.103753
#   epoch     train     valid
# 0    26  0.122626  0.105195
#   epoch     train     valid
# 0    27  0.118738  0.099222
#   epoch     train     valid
# 0    28  0.117837  0.098785
#   epoch    train    valid
# 0    29  0.11569  0.09513
#   epoch     train     valid
# 0    30  0.114565  0.094842
#   epoch     train     valid
# 0    31  0.110797  0.096483
#   epoch     train     valid
# 0    32  0.109097  0.090255
#   epoch     train     valid
# 0    33  0.108803  0.093032
#   epoch     train     valid
# 0    34  0.108947  0.089721
#   epoch     train     valid
# 0    35  0.106661  0.088288
#   epoch     train     valid
# 0    36  0.104597  0.086112
#   epoch     train     valid
# 0    37  0.102286  0.090432
#   epoch    train     valid
# 0    38  0.09948  0.088488
#   epoch     train     valid
# 0    39  0.099154  0.087099
#   epoch     train     valid
# 0    40  0.096251  0.087448
#   epoch   train     valid
# 0    41  0.0961  0.085777
#   epoch     train     valid
# 0    42  0.093695  0.085478
#   epoch    train    valid
# 0    43  0.09405  0.08115
#   epoch     train     valid
# 0    44  0.092056  0.087991
#   epoch     train     valid
# 0    45  0.090983  0.080968
#   epoch     train     valid
# 0    46  0.088893  0.083512
#   epoch     train     valid
# 0    47  0.088975  0.080735
#   epoch     train     valid
# 0    48  0.087857  0.081384
#   epoch     train     valid
# 0    49  0.085711  0.079385
#   epoch     train     valid
# 0    50  0.086081  0.078774
#   epoch     train     valid
# 0    51  0.084715  0.079382
#   epoch     train     valid
# 0    52  0.084569  0.080451
#   epoch     train     valid
# 0    53  0.083466  0.081558
#   epoch     train     valid
# 0    54  0.082233  0.077063
#   epoch     train     valid
# 0    55  0.081887  0.077682
#   epoch     train     valid
# 0    56  0.082405  0.075722
#   epoch     train     valid
# 0    57  0.080496  0.075245
#   epoch   train     valid
# 0    58  0.0814  0.077189
#   epoch     train     valid
# 0    59  0.081083  0.078975
#   epoch    train   valid
# 0    60  0.07881  0.0753
#   epoch     train     valid
# 0    61  0.078352  0.075006
#   epoch     train     valid
# 0    62  0.079056  0.077492
#   epoch     train     valid
# 0    63  0.078568  0.078146
#   epoch     train     valid
# 0    64  0.077406  0.075193
#   epoch     train     valid
# 0    65  0.076785  0.076099
#   epoch     train     valid
# 0    66  0.078066  0.075146
#   epoch     train     valid
# 0    67  0.076904  0.072955
#   epoch     train     valid
# 0    68  0.076652  0.073207
#   epoch     train    valid
# 0    69  0.075187  0.07545
#   epoch     train     valid
# 0    70  0.074387  0.074861
#   epoch     train    valid
# 0    71  0.073408  0.07344
#   epoch     train     valid
# 0    72  0.074355  0.074226
#   epoch     train     valid
# 0    73  0.073192  0.071945
#   epoch     train     valid
# 0    74  0.073625  0.072156
#   epoch     train     valid
# 0    75  0.073218  0.072513
#   epoch     train     valid
# 0    76  0.072163  0.071447
#   epoch     train     valid
# 0    77  0.072094  0.073636
#   epoch     train     valid
# 0    78  0.071014  0.071991
#   epoch   train     valid
# 0    79  0.0713  0.073723
#   epoch     train     valid
# 0    80  0.071037  0.074185
#   epoch     train     valid
# 0    81  0.070812  0.071214
#   epoch     train     valid
# 0    82  0.071732  0.068244
#   epoch     train     valid
# 0    83  0.069925  0.068684
#   epoch     train   valid
# 0    84  0.069464  0.0714
#   epoch     train     valid
# 0    85  0.069833  0.069304
#   epoch     train     valid
# 0    86  0.070471  0.069802
#   epoch   train     valid
# 0    87  0.0694  0.068808
#   epoch     train     valid
# 0    88  0.068173  0.069523
#   epoch     train     valid
# 0    89  0.067936  0.068963
#   epoch    train    valid
# 0    90  0.06875  0.07297
#   epoch    train     valid
# 0    91  0.06802  0.069925
#   epoch     train     valid
# 0    92  0.067682  0.067568
#   epoch     train     valid
# 0    93  0.067009  0.074025
#   epoch     train     valid
# 0    94  0.066581  0.067852
#   epoch     train     valid
# 0    95  0.065539  0.067926
#   epoch     train     valid
# 0    96  0.065515  0.067971
#   epoch     train     valid
# 0    97  0.064634  0.066645
#   epoch     train     valid
# 0    98  0.065074  0.067094
#   epoch     train     valid
# 0    99  0.064916  0.066132
#   epoch     train     valid
# 0   100  0.064356  0.063753
#   epoch     train     valid
# 0   101  0.063719  0.069267
#   epoch     train     valid
# 0   102  0.063575  0.065864
#   epoch     train     valid
# 0   103  0.063897  0.065822
#   epoch     train     valid
# 0   104  0.062591  0.065244
#   epoch     train     valid
# 0   105  0.061447  0.068501
#   epoch     train     valid
# 0   106  0.062537  0.065017
#   epoch     train     valid
# 0   107  0.062178  0.067231
#   epoch     train     valid
# 0   108  0.061486  0.064563
#   epoch    train     valid
# 0   109  0.06072  0.065986
#   epoch     train     valid
# 0   110  0.061178  0.063666
#   epoch     train    valid
# 0   111  0.059791  0.06444
#   epoch     train     valid
# 0   112  0.060823  0.063184
#   epoch     train     valid
# 0   113  0.060187  0.065042
#   epoch     train     valid
# 0   114  0.060378  0.067245
#   epoch     train     valid
# 0   115  0.060691  0.064777
#   epoch     train    valid
# 0   116  0.059312  0.06561
#   epoch     train     valid
# 0   117  0.059226  0.063426
#   epoch    train     valid
# 0   118  0.05865  0.064979
#   epoch     train     valid
# 0   119  0.057793  0.060718
#   epoch     train     valid
# 0   120  0.057979  0.063965
#   epoch     train     valid
# 0   121  0.057522  0.063292
#   epoch     train     valid
# 0   122  0.058226  0.062603
#   epoch    train     valid
# 0   123  0.05687  0.057076
#   epoch     train     valid
# 0   124  0.056852  0.057869
#   epoch    train     valid
# 0   125  0.05623  0.058523
#   epoch     train     valid
# 0   126  0.056078  0.063132
#   epoch     train     valid
# 0   127  0.055564  0.060686
#   epoch     train     valid
# 0   128  0.055278  0.059019
#   epoch     train     valid
# 0   129  0.054989  0.058801
#   epoch     train     valid
# 0   130  0.054689  0.059906
#   epoch     train     valid
# 0   131  0.054665  0.057743
#   epoch     train     valid
# 0   132  0.054797  0.061571
#   epoch     train   valid
# 0   133  0.054859  0.0594
# --> early stopping

# %%
enc_attention_weights = torch.cat(model.attention_weights, 0)

# %%
enc_attention_weights.shape
# Out:
# torch.Size([80, 100, 100])

# %%
fig, ax = plt.subplots()
im = ax.imshow(enc_attention_weights[0])

# %%
fig, ax = plt.subplots()
im = ax.imshow(enc_attention_weights[1])

# %% [markdown]
# ## Evaluation

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_eval")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_eval")

eval_dataset = KVyQVx(params)

# %%
criterion = R2()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 0.9362081848084927

# %%
criterion = RMSE()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 29.92879068851471

# %%
criterion = variance()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 503.13164710998535

# %% [markdown]
# ## QQplot

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_eval")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_eval")

eval_dataset = KVyQVx(params)

# %%
results = prediction_prime(obj,eval_dataset)
# Out:
# /home/jean-marie/dev/01-packages/steams_pkg/steams/trainer.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results,tmp_df],ignore_index=True,axis=0)

# %%
pred_name = ['pred_' + v for v in eval_dataset.VALUE_X]

fig, ax= plt.subplots(figsize=(14, 12))
ax.scatter(results.loc[:,eval_dataset.VALUE_X],results.loc[:,pred_name], linewidth=2.0,c="black")
ax.axline((0, 0), slope=1., color='blue')
# ax.set_xlim(0, 2.5)
ax.set_ylim(results.loc[:,pred_name].min().item()-0.5, results.loc[:,pred_name].max().item()+0.5)
ax.set(xlabel='observations', ylabel='predictions')

fig_filename = os.path.join(parent_dir,'fig','1c-qqplot.png')
plt.savefig(fig_filename, dpi = 300)

# %% [markdown]
# ## Illustration of a 2d-map prediction

# %%
params = {
        "class" : "KVyQVx",
        "Y":{
          "path": "",
          "KEY":["x","y"],
          "VALUE": ["sensor_hq"],
          "nb_location" : 1000,
          "history_length": 0,
          "nb_sampling": 1000
        },
        "X":{
          "path": "",
          "QUERY":["x","y"],
          "VALUE": ["ref"],
          "nb_location" : 6400,
          "gap_length": 0,
          "horizon_length":0,
          "nb_sampling": 1000
        }
    }

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_eval")
params['X']['path'] = os.path.join(parent_dir,"session","synth_all_6400")

eval_dataset = KVyQVx(params)

# %%
eval_dataset[0][0].shape
# Out:
# torch.Size([1000, 2])

# %%
eval_dataset.scale(True)
KEY_Y,VALUE_Y,QUERY_X, VALUE_X = eval_dataset[0]

# %%
QUERY_res, VALUE_res = obj.predict(KEY_Y,VALUE_Y,QUERY_X,eval_dataset)

# %%
# output
VALUE_X = torch.reshape(VALUE_X,(1,VALUE_X.shape[0],VALUE_X.shape[1]))
#QUERY_X_unscale = eval_dataset.unscale(QUERY_X,"QUERY").to(device)
VALUE_X_unscale = eval_dataset.unscale(VALUE_X,"VALUE_X").to(device)

# %%
tmp = np.concatenate((QUERY_res, VALUE_res,VALUE_X_unscale),2)
tmp = np.reshape(tmp,(tmp.shape[1],tmp.shape[2]))
results = pd.DataFrame(tmp,columns=['x','y','values','truth'])

# %%
# predictors
VALUE_Y = torch.reshape(VALUE_Y,(1,VALUE_Y.shape[0],VALUE_Y.shape[1]))
KEY_Y = torch.reshape(KEY_Y,(1,KEY_Y.shape[0],KEY_Y.shape[1]))
KEY_Y_unscale = eval_dataset.unscale(KEY_Y,"KEY").to(device)
VALUE_Y_unscale = eval_dataset.unscale(VALUE_Y,"VALUE_Y").to(device)

tmp = np.concatenate((KEY_Y_unscale, VALUE_Y_unscale),2)
tmp = np.reshape(tmp,(tmp.shape[1],tmp.shape[2]))
predictors = pd.DataFrame(tmp,columns=['x','y','values'])

# %%
vmax = np.array(
    results['values'].max(),
    results['truth'].max()).max()

vmin = np.array(
    results['values'].min(),
    results['truth'].min()).min()

# %%
foo = predictors.copy()
# unique_rmse = np.unique(foo["rmse"])
# unique_variance = np.unique(foo["variance"])
# symbol_rmse = [i for i in range(1,len(unique_rmse)+1)]
# symbol_variance = ['o','v','s','p','s','D']#[i for i in range(len(unique_variance))]

# %%
# results

# %%
fig = plt.figure(constrained_layout=True,figsize=(12, 3))
gs = GridSpec(1, 2, figure=fig)

ax1 = fig.add_subplot(gs[0,0])
c1 = ax1.scatter(x=results["x"], y=results["y"], s=2,c=results['values'],vmin=vmin,vmax=vmax)
#ax1.set(ylabel='Y (meters)')
ax1.set(xlabel='X (meters)')
plt.gca().set_aspect("equal")

ax2 = fig.add_subplot(gs[0,1])
c2 = ax2.scatter(x=results["x"], y=results["y"], s=2,c=results['truth'],vmin=vmin,vmax=vmax)
#ax2.set(ylabel='Y (meters)')
ax2.set(xlabel='X (meters)')
plt.gca().set_aspect("equal")

fig.colorbar(c1, ax=ax1,label ='meters')
fig.colorbar(c2, ax=ax2,label ='meters')

fig_filename = os.path.join(parent_dir,'fig','illustration_prediction.png')
plt.savefig(fig_filename, dpi = 300)
