# %%
import pandas as pd
import os
import json
import torch
import numpy as np
from torch.utils.data import DataLoader
from steams.data import KVyQVx
from steams.models.transformer import Transf_enc_dec
from steams.trainer import AttentionTrainer,train, evaluation, prediction_prime, ensemble_prime
from steams.criterion import R2,RMSE,variance
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import geopandas as gpd

# %%
parent_dir = os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), os.pardir))

# %%
resdir = os.path.join(parent_dir,'results')
figdir = os.path.join(parent_dir,'fig')
if not os.path.exists(figdir):
    os.makedirs(figdir)
if not os.path.exists(resdir):
    os.makedirs(resdir)

# %%
if torch.cuda.is_available():
    cuda_name = "1"
    num_workers=0
    pin_memory = True
    device = torch.device('cuda'+":"+cuda_name)
    #device = torch.device('cuda')
else:
    num_workers = 4
    pin_memory = False
    device = torch.device('cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## train/valid dataset

# %%
params = {
        "class" : "KVyQVx",
        "Y":{
          "path": "",
          "KEY":["x","y"],
          "VALUE": ["sensor_hq"],
          "nb_location" : 1000,
          "history_length": 0,
          "nb_sampling": 100
        },
        "X":{
          "path": "",
          "QUERY":["x","y"],
          "VALUE": ["sensor_hq"],
          "nb_location" : 1000,
          "gap_length": 0,
          "horizon_length":0,
          "nb_sampling": 100
        }
    }

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_train")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_train")

train_dataset = KVyQVx(params)

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_valid")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_valid")

valid_dataset = KVyQVx(params)

# %%
#train_dataset[0]

# %% [markdown]
# ## model, optimizer, criterion, scheduler

# %%
#model
model = Transf_enc_dec(input_k=2,input_q=2, input_v=1, hidden_size=32,num_heads=8,dim_feedforward=10,num_blk=2,dropout=0.1)

# %%
# optimzer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4) #8e-3
#optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# criterion
criterion = torch.nn.MSELoss()

# AttentionTrainer object
obj = AttentionTrainer(model,device)
obj.init_optimizer(optimizer)
obj.init_criterion(criterion)

# %% [markdown]
# ## Training

# %%
# training
train(obj,train_dataset,valid_dataset,niter=200,n_iter_stop=10,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
#   epoch     train     valid
# 0     0  1.005493  0.995954
#   epoch     train     valid
# 0     1  1.001415  0.999471
#   epoch     train     valid
# 0     2  0.994485  0.998427
#   epoch     train     valid
# 0     3  0.998066  0.996314
#   epoch     train    valid
# 0     4  0.996013  0.99633
#   epoch     train     valid
# 0     5  0.996511  0.996091
#   epoch     train     valid
# 0     6  0.988692  0.992042
#   epoch     train    valid
# 0     7  0.985636  0.97936
#   epoch     train     valid
# 0     8  0.979718  0.972964
#   epoch     train    valid
# 0     9  0.952438  0.93501
#   epoch     train     valid
# 0    10  0.913698  0.874182
#   epoch    train     valid
# 0    11  0.83205  0.761394
#   epoch    train     valid
# 0    12  0.70584  0.605558
#   epoch     train     valid
# 0    13  0.559381  0.455257
#   epoch     train     valid
# 0    14  0.452514  0.375234
#   epoch     train     valid
# 0    15  0.397097  0.337055
#   epoch     train     valid
# 0    16  0.370961  0.321376
#   epoch     train     valid
# 0    17  0.362477  0.312446
#   epoch     train     valid
# 0    18  0.353262  0.310053
#   epoch     train     valid
# 0    19  0.348315  0.300992
#   epoch     train     valid
# 0    20  0.342448  0.298634
#   epoch     train     valid
# 0    21  0.341272  0.293336
#   epoch     train     valid
# 0    22  0.335744  0.290555
#   epoch     train     valid
# 0    23  0.330014  0.290195
#   epoch     train    valid
# 0    24  0.329989  0.28561
#   epoch     train     valid
# 0    25  0.326388  0.286384
#   epoch     train    valid
# 0    26  0.326204  0.28217
#   epoch     train     valid
# 0    27  0.321123  0.279926
#   epoch     train     valid
# 0    28  0.316278  0.281519
#   epoch     train     valid
# 0    29  0.315114  0.274057
#   epoch     train     valid
# 0    30  0.313047  0.274142
#   epoch     train     valid
# 0    31  0.309822  0.273125
#   epoch     train     valid
# 0    32  0.307592  0.270867
#   epoch    train     valid
# 0    33  0.30495  0.264131
#   epoch     train     valid
# 0    34  0.304442  0.264908
#   epoch     train     valid
# 0    35  0.303645  0.262214
#   epoch     train     valid
# 0    36  0.298793  0.259116
#   epoch     train     valid
# 0    37  0.297649  0.257692
#   epoch     train     valid
# 0    38  0.293551  0.256233
#   epoch     train     valid
# 0    39  0.290522  0.249188
#   epoch     train     valid
# 0    40  0.287642  0.248059
#   epoch     train     valid
# 0    41  0.282247  0.243761
#   epoch    train     valid
# 0    42  0.27999  0.242554
#   epoch     train     valid
# 0    43  0.278924  0.238511
#   epoch     train     valid
# 0    44  0.275342  0.233912
#   epoch     train    valid
# 0    45  0.271044  0.23004
#   epoch     train    valid
# 0    46  0.267186  0.22633
#   epoch     train     valid
# 0    47  0.263352  0.218078
#   epoch     train     valid
# 0    48  0.256367  0.217239
#   epoch     train     valid
# 0    49  0.248845  0.207406
#   epoch     train     valid
# 0    50  0.243876  0.201165
#   epoch     train     valid
# 0    51  0.239144  0.193257
#   epoch     train     valid
# 0    52  0.231666  0.186804
#   epoch    train    valid
# 0    53  0.22542  0.18247
#   epoch     train     valid
# 0    54  0.219836  0.175517
#   epoch     train    valid
# 0    55  0.211066  0.16832
#   epoch     train     valid
# 0    56  0.206411  0.162858
#   epoch     train     valid
# 0    57  0.199987  0.159314
#   epoch     train     valid
# 0    58  0.196177  0.155847
#   epoch     train    valid
# 0    59  0.190613  0.15089
#   epoch     train     valid
# 0    60  0.186168  0.147778
#   epoch     train     valid
# 0    61  0.182933  0.143446
#   epoch     train     valid
# 0    62  0.179901  0.141316
#   epoch     train     valid
# 0    63  0.175526  0.139214
#   epoch     train     valid
# 0    64  0.173171  0.136202
#   epoch     train     valid
# 0    65  0.167169  0.131359
#   epoch     train    valid
# 0    66  0.165226  0.12984
#   epoch     train     valid
# 0    67  0.164666  0.126879
#   epoch     train     valid
# 0    68  0.161307  0.123623
#   epoch     train     valid
# 0    69  0.157062  0.121119
#   epoch    train    valid
# 0    70  0.15609  0.12092
#   epoch     train     valid
# 0    71  0.151936  0.118551
#   epoch     train    valid
# 0    72  0.150778  0.11847
#   epoch    train     valid
# 0    73  0.14687  0.115781
#   epoch     train     valid
# 0    74  0.146135  0.112145
#   epoch     train     valid
# 0    75  0.146438  0.113164
#   epoch     train     valid
# 0    76  0.142554  0.110828
#   epoch     train     valid
# 0    77  0.142212  0.110506
#   epoch     train     valid
# 0    78  0.140628  0.110084
#   epoch   train    valid
# 0    79  0.1382  0.10848
#   epoch     train     valid
# 0    80  0.135919  0.105361
#   epoch     train     valid
# 0    81  0.134897  0.104468
#   epoch     train    valid
# 0    82  0.132451  0.10389
#   epoch     train     valid
# 0    83  0.130127  0.102984
#   epoch     train     valid
# 0    84  0.130501  0.101612
#   epoch     train     valid
# 0    85  0.127714  0.099242
#   epoch     train     valid
# 0    86  0.127265  0.100306
#   epoch     train     valid
# 0    87  0.125086  0.098603
#   epoch     train     valid
# 0    88  0.123319  0.097678
#   epoch     train     valid
# 0    89  0.121767  0.097088
#   epoch     train     valid
# 0    90  0.120778  0.095241
#   epoch     train     valid
# 0    91  0.119405  0.094656
#   epoch     train     valid
# 0    92  0.118607  0.094523
#   epoch     train     valid
# 0    93  0.117462  0.092656
#   epoch     train     valid
# 0    94  0.116577  0.091852
#   epoch     train     valid
# 0    95  0.114629  0.090522
#   epoch     train    valid
# 0    96  0.114157  0.09009
#   epoch     train    valid
# 0    97  0.113111  0.08906
#   epoch    train    valid
# 0    98  0.11114  0.08788
#   epoch     train     valid
# 0    99  0.110311  0.089118
#   epoch     train     valid
# 0   100  0.109006  0.087892
#   epoch   train     valid
# 0   101  0.1081  0.086663
#   epoch    train     valid
# 0   102  0.10678  0.085292
#   epoch     train    valid
# 0   103  0.106471  0.08563
#   epoch     train     valid
# 0   104  0.104537  0.083259
#   epoch     train     valid
# 0   105  0.104964  0.083725
#   epoch    train     valid
# 0   106  0.10364  0.084384
#   epoch     train     valid
# 0   107  0.103295  0.083398
#   epoch     train     valid
# 0   108  0.103084  0.084606
#   epoch     train     valid
# 0   109  0.101947  0.082863
#   epoch     train     valid
# 0   110  0.102217  0.083077
#   epoch     train     valid
# 0   111  0.101051  0.081263
#   epoch     train     valid
# 0   112  0.100347  0.081391
#   epoch     train     valid
# 0   113  0.099905  0.081075
#   epoch     train     valid
# 0   114  0.099508  0.080263
#   epoch     train     valid
# 0   115  0.098162  0.080265
#   epoch     train     valid
# 0   116  0.098142  0.078952
#   epoch    train     valid
# 0   117  0.09684  0.079475
#   epoch     train     valid
# 0   118  0.095706  0.079183
#   epoch     train     valid
# 0   119  0.096302  0.078173
#   epoch     train     valid
# 0   120  0.096771  0.078981
#   epoch     train     valid
# 0   121  0.096407  0.078209
#   epoch     train     valid
# 0   122  0.094965  0.078028
#   epoch     train     valid
# 0   123  0.094848  0.076942
#   epoch     train     valid
# 0   124  0.093622  0.077055
#   epoch     train     valid
# 0   125  0.094786  0.076582
#   epoch    train     valid
# 0   126  0.09416  0.077709
#   epoch     train     valid
# 0   127  0.094093  0.075515
#   epoch    train     valid
# 0   128  0.09237  0.076101
#   epoch     train     valid
# 0   129  0.092237  0.075758
#   epoch    train    valid
# 0   130  0.09099  0.07544
#   epoch     train     valid
# 0   131  0.091139  0.074936
#   epoch     train     valid
# 0   132  0.091631  0.075662
#   epoch    train     valid
# 0   133  0.09123  0.075269
#   epoch     train    valid
# 0   134  0.091143  0.07405
#   epoch     train     valid
# 0   135  0.091225  0.075504
#   epoch     train     valid
# 0   136  0.089488  0.074814
#   epoch     train     valid
# 0   137  0.090309  0.073228
#   epoch     train     valid
# 0   138  0.089954  0.073679
#   epoch     train    valid
# 0   139  0.090322  0.07442
#   epoch     train     valid
# 0   140  0.088716  0.073432
#   epoch    train     valid
# 0   141  0.08915  0.073606
#   epoch     train     valid
# 0   142  0.087694  0.073178
#   epoch     train     valid
# 0   143  0.088749  0.073115
#   epoch     train     valid
# 0   144  0.087318  0.072201
#   epoch     train     valid
# 0   145  0.088444  0.071814
#   epoch     train     valid
# 0   146  0.087519  0.072777
#   epoch     train    valid
# 0   147  0.086501  0.07217
#   epoch     train     valid
# 0   148  0.086039  0.071822
#   epoch     train     valid
# 0   149  0.085953  0.070491
#   epoch     train     valid
# 0   150  0.085255  0.071014
#   epoch    train     valid
# 0   151  0.08517  0.069899
#   epoch     train     valid
# 0   152  0.086143  0.070819
#   epoch     train     valid
# 0   153  0.085691  0.071459
#   epoch     train     valid
# 0   154  0.084618  0.070209
#   epoch     train     valid
# 0   155  0.083959  0.070368
#   epoch     train     valid
# 0   156  0.084641  0.070349
#   epoch     train     valid
# 0   157  0.084125  0.070449
#   epoch     train     valid
# 0   158  0.083631  0.069718
#   epoch     train     valid
# 0   159  0.083519  0.070183
#   epoch     train    valid
# 0   160  0.082393  0.07026
#   epoch     train     valid
# 0   161  0.083202  0.069422
#   epoch     train     valid
# 0   162  0.082715  0.069587
#   epoch     train     valid
# 0   163  0.083048  0.068767
#   epoch     train     valid
# 0   164  0.081444  0.068427
#   epoch     train     valid
# 0   165  0.082911  0.067573
#   epoch     train     valid
# 0   166  0.082199  0.067842
#   epoch     train    valid
# 0   167  0.082149  0.06774
#   epoch    train     valid
# 0   168  0.08182  0.068618
#   epoch     train     valid
# 0   169  0.081103  0.068555
#   epoch    train    valid
# 0   170  0.08157  0.06893
#   epoch     train     valid
# 0   171  0.081439  0.068274
#   epoch     train     valid
# 0   172  0.080848  0.069138
#   epoch     train    valid
# 0   173  0.081473  0.06935
#   epoch     train     valid
# 0   174  0.080443  0.067743
#   epoch     train     valid
# 0   175  0.080888  0.065711
#   epoch     train     valid
# 0   176  0.080126  0.065893
#   epoch     train     valid
# 0   177  0.079116  0.066763
#   epoch     train     valid
# 0   178  0.079748  0.068269
#   epoch    train    valid
# 0   179  0.07985  0.06709
#   epoch     train     valid
# 0   180  0.079544  0.068366
#   epoch     train    valid
# 0   181  0.079778  0.06765
#   epoch     train     valid
# 0   182  0.079353  0.066812
#   epoch     train     valid
# 0   183  0.079452  0.067365
#   epoch     train    valid
# 0   184  0.079639  0.06834
#   epoch     train     valid
# 0   185  0.078725  0.067999
# --> early stopping

# %%
enc_attention_weights = torch.cat(model.enc_transf.attention_weights, 0)

# %%
fig, ax = plt.subplots()
im = ax.imshow(enc_attention_weights[0,0])

# %%
fig, ax = plt.subplots()
im = ax.imshow(enc_attention_weights[0,1])

# %%
fig, ax = plt.subplots()
im = ax.imshow(model.cross_att.weights[0,0])

# %%
fig, ax = plt.subplots()
im = ax.imshow(model.cross_att.weights[0,1])

# %% [markdown]
# ## Evaluation

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_eval")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_eval")

eval_dataset = KVyQVx(params)

# %%
criterion = R2()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 0.9179554618895054

# %%
criterion = RMSE()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 33.56473422050476

# %%
criterion = variance()
obj.init_criterion(criterion)

# %%
evaluation(obj,eval_dataset,batch_size=64,shuffle=True,num_workers=num_workers,pin_memory=pin_memory,resdir=None)
# Out:
# 654.0889205932617

# %% [markdown]
# ## QQplot

# %%
params['Y']['path'] = os.path.join(parent_dir,"session","synth_1000_Y_eval")
params['X']['path'] = os.path.join(parent_dir,"session","synth_1000_X_eval")

eval_dataset = KVyQVx(params)

# %%
results = prediction_prime(obj,eval_dataset)
# Out:
# /home/jean-marie/dev/01-packages/steams_pkg/steams/trainer.py:163: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results,tmp_df],ignore_index=True,axis=0)

# %%
pred_name = ['pred_' + v for v in eval_dataset.VALUE_X]

fig, ax= plt.subplots(figsize=(14, 12))
ax.scatter(results.loc[:,eval_dataset.VALUE_X],results.loc[:,pred_name], linewidth=2.0,c="black")
ax.axline((0, 0), slope=1., color='blue')
# ax.set_xlim(0, 2.5)
ax.set_ylim(results.loc[:,pred_name].min().item()-0.5, results.loc[:,pred_name].max().item()+0.5)
ax.set(xlabel='observations', ylabel='predictions')

fig_filename = os.path.join(parent_dir,'fig','1c-qqplot.png')
plt.savefig(fig_filename, dpi = 300)
